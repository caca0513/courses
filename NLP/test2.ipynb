# %%
import spacy
from tabulate import tabulate
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_lg')

# %%
text = ("When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him         seriously. “I can tell you very senior CEOs of major American         car companies would shake my hand and turn away because I wasn’t         worth talking to,” said Thrun, now the co-founder and CEO of        online higher education startup Udacity, in an interview with  Recode earlier this week.")
doc = nlp(text)

# %%
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Sebastian Thrun PERSON
# Google ORG
# 2007 DATE
# American NORP
# Thrun PERSON
# Udacity PERSON
# Recode PERSON
# earlier this week DATE

# %%
print(tabulate([[token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop]for token in doc], 
               headers=['text', 'lemma_', 'pos_', 'tag_', 'dep_', 'shape_', 'is_alpha', 'is_stop']))
# Out:
# text       lemma_     pos_    tag_    dep_      shape_    is_alpha    is_stop
# ---------  ---------  ------  ------  --------  --------  ----------  ---------
# When       when       ADV     WRB     advmod    Xxxx      True        False
# Sebastian  sebastian  PROPN   NNP     compound  Xxxxx     True        False
# Thrun      thrun      PROPN   NNP     nsubj     Xxxxx     True        False
# started    start      VERB    VBD     advcl     xxxx      True        False
# working    work       VERB    VBG     xcomp     xxxx      True        False
# on         on         ADP     IN      prep      xx        True        False
# self       self       NOUN    NN      npadvmod  xxxx      True        False
# -          -          PUNCT   HYPH    punct     -         False       False
# driving    drive      VERB    VBG     amod      xxxx      True        False
# cars       car        NOUN    NNS     pobj      xxxx      True        False
# at         at         ADP     IN      prep      xx        True        False
# Google     google     PROPN   NNP     pobj      Xxxxx     True        False
# in         in         ADP     IN      prep      xx        True        False
# 2007       2007       NUM     CD      pobj      dddd      False       False
# ,          ,          PUNCT   ,       punct     ,         False       False
# few        few        ADJ     JJ      amod      xxx       True        False
# people     people     NOUN    NNS     nsubj     xxxx      True        False
# outside    outside    ADV     RB      advmod    xxxx      True        False
# of         of         ADP     IN      prep      xx        True        False
# the        the        DET     DT      det       xxx       True        False
# company    company    NOUN    NN      pobj      xxxx      True        False
# took       take       VERB    VBD     ROOT      xxxx      True        False
# him        -PRON-     PRON    PRP     dobj      xxx       True        False
#                       SPACE   _SP                         False       False
# seriously  seriously  ADV     RB      advmod    xxxx      True        False
# .          .          PUNCT   .       punct     .         False       False
# “          “          INTJ    UH      ROOT      “         False       False
# I          -PRON-     PRON    PRP     nsubj     X         True        False
# can        can        VERB    MD      aux       xxx       True        False
# tell       tell       VERB    VB      ccomp     xxxx      True        False
# you        -PRON-     PRON    PRP     dative    xxx       True        False
# very       very       ADV     RB      advmod    xxxx      True        False
# senior     senior     ADJ     JJ      amod      xxxx      True        False
# CEOs       ceo        NOUN    NNS     nsubj     XXXx      True        False
# of         of         ADP     IN      prep      xx        True        False
# major      major      ADJ     JJ      amod      xxxx      True        False
# American   american   ADJ     JJ      amod      Xxxxx     True        False
#                       SPACE   _SP                         False       False
# car        car        NOUN    NN      compound  xxx       True        False
# companies  company    NOUN    NNS     pobj      xxxx      True        False
# would      would      VERB    MD      aux       xxxx      True        False
# shake      shake      VERB    VB      ccomp     xxxx      True        False
# my         -PRON-     ADJ     PRP$    poss      xx        True        False
# hand       hand       NOUN    NN      dobj      xxxx      True        False
# and        and        CCONJ   CC      cc        xxx       True        False
# turn       turn       VERB    VB      conj      xxxx      True        False
# away       away       ADV     RB      advmod    xxxx      True        False
# because    because    ADP     IN      mark      xxxx      True        False
# I          -PRON-     PRON    PRP     nsubj     X         True        False
# was        be         VERB    VBD     advcl     xxx       True        False
# n’t        not        ADV     RB      neg       x’x       False       False
#                       SPACE   _SP                         False       False
# worth      worth      ADJ     JJ      acomp     xxxx      True        False
# talking    talk       VERB    VBG     xcomp     xxxx      True        False
# to         to         ADP     IN      prep      xx        True        False
# ,          ,          PUNCT   ,       punct     ,         False       False
# ”          ”          NOUN    NN      punct     ”         False       False
# said       say        VERB    VBD     ROOT      xxxx      True        False
# Thrun      thrun      PROPN   NNP     nsubj     Xxxxx     True        False
# ,          ,          PUNCT   ,       punct     ,         False       False
# now        now        ADV     RB      advmod    xxx       True        False
# the        the        DET     DT      det       xxx       True        False
# co         co         PROPN   NNP     punct     xx        True        False
# -          -          PUNCT   HYPH    punct     -         False       False
# founder    founder    NOUN    NN      punct     xxxx      True        False
# and        and        CCONJ   CC      cc        xxx       True        False
# CEO        ceo        PROPN   NNP     conj      XXX       True        False
# of         of         ADP     IN      prep      xx        True        False
#                       SPACE   _SP                         False       False
# online     online     ADJ     JJ      amod      xxxx      True        False
# higher     high       ADJ     JJR     amod      xxxx      True        False
# education  education  NOUN    NN      compound  xxxx      True        False
# startup    startup    NOUN    NN      compound  xxxx      True        False
# Udacity    udacity    PROPN   NNP     pobj      Xxxxx     True        False
# ,          ,          PUNCT   ,       punct     ,         False       False
# in         in         ADP     IN      prep      xx        True        False
# an         an         DET     DT      det       xx        True        False
# interview  interview  NOUN    NN      pobj      xxxx      True        False
# with       with       ADP     IN      prep      xxxx      True        False
#                       SPACE                               False       False
# Recode     recode     PROPN   NNP     pobj      Xxxxx     True        False
# earlier    earlier    ADV     RBR     advmod    xxxx      True        False
# this       this       DET     DT      det       xxxx      True        False
# week       week       NOUN    NN      npadvmod  xxxx      True        False
# .          .          PUNCT   .       punct     .         False       False

# %%
displacy.serve(doc, style='dep')
# Out:
#     Serving on port 5000...
#     Using the 'dep' visualizer
# 127.0.0.1 - - [04/Sep/2018 23:06:12] "GET / HTTP/1.1" 200 56634
# 127.0.0.1 - - [04/Sep/2018 23:06:13] "GET /favicon.ico HTTP/1.1" 200 56634
#     Shutting down server on port 5000.

# %%
print(tabulate([[ent.text, ent.start_char, ent.end_char, ent.label_]for ent in doc.ents], 
               headers=['text', 'start_char', 'end_char', 'label_']))
# Out:
# text                 start_char    end_char  label_
# -----------------  ------------  ----------  --------
# Sebastian Thrun               5          20  PERSON
# Google                       61          67  ORG
# 2007                         71          75  DATE
# American                    181         189  NORP
# Thrun                       295         300  PERSON
# Udacity                     371         378  PERSON
# Recode                      402         408  PERSON
# earlier this week           409         426  DATE

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Sebastian Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started working on self-driving cars at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , few people outside of the company took him         seriously. “I can tell you very senior CEOs of major
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#          car companies would shake my hand and turn away because I wasn’t         worth talking to,” said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , now the co-founder and CEO of        online higher education startup
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Udacity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , in an interview with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Recode
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     earlier this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div>

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="13175" height="1187.0" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">When</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Sebastian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Thrun</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">started</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">working</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">self-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">driving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">cars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Google</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">2007,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">few</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">outside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">took</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">him</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">        </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">seriously. “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">can</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">tell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">senior</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">CEOs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentCo

# %%
print(tabulate([[token1.text, token2.text, token1.similarity(token2)] for token1 in doc for token2 in doc], 
               headers=['token1', 'token2', 'similarity']))
# Out:
# token1     token2       similarity
# ---------  ---------  ------------
# When       When        1
# When       Sebastian  -0.00702033
# When       Thrun       0
# When       started     0.598991
# When       working     0.573928
# When       on          0.425128
# When       self        0.400002
# When       -           0.0865491
# When       driving     0.48581
# When       cars        0.330908
# When       at          0.363292
# When       Google      0.276873
# When       in          0.487571
# When       2007        0.13787
# When       ,           0.349346
# When       few         0.600293
# When       people      0.585984
# When       outside     0.553441
# When       of          0.455727
# When       the         0.619606
# When       company     0.412777
# When       took        0.63257
# When       him         0.683443
# When                   0
# When       seriously   0.555802
# When       .           0.437521
# When       “           0.30398
# When       I           0.515064
# When       can         0.614315
# When       tell        0.670524
# When       you         0.675737
# When       very        0.557945
# When       senior      0.336538
# When       CEOs       -0.138322
# When       of          0.455727
# When       major       0.417549
# When       American    0.263264
# When                   0
# When       car         0.403185
# When       companies   0.34668
# When       would       0.685863
# When       shake       0.37946
# When       my          0.564774
# When       hand        0.564677
# When       and         0.584835
# When       turn        0.648962
# When       away        0.607173
# When       because     0.819474
# When       I           0.515064
# When       was         0.666223
# When       n’t         0.471098
# When                   0
# When       worth       0.411679
# When       talking     0.611651
# When       to          0.576736
# When       ,           0.349346
# When       ”           0.348711
# When       said        0.52024
# When       Thrun       0
# When       ,           0.349346
# When       now         0.651861
# When       the         0.619606
# When       co          0.142792
# When       -           0.0865491
# When       founder     0.227841
# When       and         0.584835
# When       CEO         0.0394147
# When       of          0.455727
# When                   0
# When       online      0.314649
# When       higher      0.433963
# When       education   0.306784
# When       startup     0.300715
# When       Udacity     0
# When       ,           0.349346
# When       in          0.487571
# When       an          0.530212
# When       interview   0.347009
# When       with        0.567431
# When                   0
# When       Recode     -0.0516174
# When       earlier     0.603529
# When       this        0.581044
# When       week        0.46838
# When       .           0.437521
# Sebastian  When       -0.00702033
# Sebastian  Sebastian   1
# Sebastian  Thrun       0
# Sebastian  started    -0.00128929
# Sebastian  working    -0.0572483
# Sebastian  on         -0.0275338
# Sebastian  self        0.0854463
# Sebastian  -          -0.0554215
# Sebastian  driving     0.0294761
# Sebastian  cars        0.0762812
# Sebastian  at          0.000280082
# Sebastian  Google      0.185563
# Sebastian  in         -0.0515842
# Sebastian  2007        0.0363751
# Sebastian  ,          -0.00262818
# Sebastian  few        -0.0448438
# Sebastian  people     -0.0338226
# Sebastian  outside    -0.0583409
# Sebastian  of         -0.0989138
# Sebastian  the        -0.0757649
# Sebastian  company    -0.0455807
# Sebastian  took       -0.00775733
# Sebastian  him         0.0666204
# Sebastian              0
# Sebastian  seriously   0.065529
# Sebastian  .          -0.0209733
# Sebastian  “          -0.0850963
# Sebastian  I           0.254697
# Sebastian  can        -0.0110991
# Sebastian  tell        0.0595205
# Sebastian  you         0.0277332
# Sebastian  very        0.0120683
# Sebastian  senior     -0.0214916
# Sebastian  CEOs        0.103085
# Sebastian  of         -0.0989138
# Sebastian  major      -0.0121334
# Sebastian  American    0.269584
# Sebastian              0
# Sebastian  car         0.0879282
# Sebastian  companies  -0.0605623
# Sebastian  would      -0.0255111
# Sebastian  shake       0.146806
# Sebastian  my          0.0545889
# Sebastian  hand        0.0371826
# Sebastian  and        -0.039571
# Sebastian  turn        0.0175815
# Sebastian  away        0.0521382
# Sebastian  because    -0.0045022
# Sebastian  I           0.254697
# Sebastian  was         0.00330242
# Sebastian  n’t        -0.0233134
# Sebastian              0
# Sebastian  worth       0.020963
# Sebastian  talking     0.0433448
# Sebastian  to         -0.076964
# Sebastian  ,          -0.00262818
# Sebastian  ”          -0.0627904
# Sebastian  said       -0.0187926
# Sebastian  Thrun       0
# Sebastian  ,          -0.00262818
# Sebastian  now        -0.00438598
# Sebastian  the        -0.0757649
# Sebastian  co          0.218877
# Sebastian  -          -0.0554215
# Sebastian  founder    -0.0646031
# Sebastian  and        -0.039571
# Sebastian  CEO         0.246573
# Sebastian  of         -0.0989138
# Sebastian              0
# Sebastian  online     -0.00896666
# Sebastian  higher     -0.060539
# Sebastian  education   0.0384483
# Sebastian  startup     0.0113995
# Sebastian  Udacity     0
# Sebastian  ,          -0.00262818
# Sebastian  in         -0.0515842
# Sebastian  an         -0.114386
# Sebastian  interview   0.0353383
# Sebastian  with       -0.0862876
# Sebastian              0
# Sebastian  Recode      0.0127392
# Sebastian  earlier    -0.108409
# Sebastian  this        0.0328292
# Sebastian  week       -0.0256519
# Sebastian  .          -0.0209733
# Thrun      When        0
# Thrun      Sebastian   0
# Thrun      Thrun       1
# Thrun      started     0
# Thrun      working     0
# Thrun      on          0
# Thrun      self        0
# Thrun      -           0
# Thrun      driving     0
# Thrun      cars        0
# Thrun      at          0
# Thrun      Google      0
# Thrun      in          0
# Thrun      2007        0
# Thrun      ,           0
# Thrun      few         0
# Thrun      people      0
# Thrun      outside     0
# Thrun      of          0
# Thrun      the         0
# Thrun      company     0
# Thrun      took        0
# Thrun      him         0
# Thrun                  0
# Thrun      seriously   0
# Thrun      .           0
# Thrun      “           0
# Thrun      I           0
# Thrun      can         0
# Thrun      tell        0
# Thrun      you         0
# Thrun      very        0
# Thrun      senior      0
# Thrun      CEOs        0
# Thrun      of          0
# Thrun      major       0
# Thrun      American    0
# Thrun                  0
# Thrun      car         0
# Thrun      companies   0
# Thrun      would       0
# Thrun      shake       0
# Thrun      my          0
# Thrun      hand        0
# Thrun      and         0
# Thrun      turn        0
# Thrun      away        0
# Thrun      because     0
# Thrun      I           0
# Thrun      was         0
# Thrun      n’t         0
# Thrun                  0
# Thrun      worth       0
# Thrun      talking     0
# Thrun      to          0
# Thrun      ,           0
# Thrun      ”           0
# Thrun      said        0
# Thrun      Thrun       1
# Thrun      ,           0
# Thrun      now         0
# Thrun      the         0
# Thrun      co          0
# Thrun      -           0
# Thrun      founder     0
# Thrun      and         0
# Thrun      CEO         0
# Thrun      of          0
# Thrun                  0
# Thrun      online      0
# Thrun      higher      0
# Thrun      education   0
# Thrun      startup     0
# Thrun      Udacity     0
# Thrun      ,           0
# Thrun      in          0
# Thrun      an          0
# Thrun      interview   0
# Thrun      with        0
# Thrun                  0
# Thrun      Recode      0
# Thrun      earlier     0
# Thrun      this        0
# Thrun      week        0
# Thrun      .           0
# started    When        0.598991
# started    Sebastian  -0.00128929
# started    Thrun       0
# started    started     1
# started    working     0.557308
# started    on          0.428783
# started    self        0.237158
# started    -           0.145105
# started    driving     0.336747
# started    cars        0.23839
# started    at          0.331964
# started    Google      0.239677
# started    in          0.376777
# started    2007        0.23395
# started    ,           0.261742
# started    few         0.558763
# started    people      0.423032
# started    outside     0.374042
# started    of          0.331869
# started    the         0.396648
# started    company     0.386874
# started    took        0.690366
# started    him         0.464633
# started                0
# started    seriously   0.439783
# started    .           0.277835
# started    “           0.264226
# started    I           0.45407
# started    can         0.33365
# started    tell        0.426485
# started    you         0.400732
# started    very        0.407636
# started    senior      0.263765
# started    CEOs       -0.129051
# started    of          0.331869
# started    major       0.33623
# started    American    0.156017
# started                0
# started    car         0.240529
# started    companies   0.314817
# started    would       0.514952
# started    shake       0.272311
# started    my          0.511848
# started    hand        0.404263
# started    and         0.39468
# started    turn        0.436514
# started    away        0.471826
# started    because     0.487433
# started    I           0.45407
# started    was         0.617433
# started    n’t         0.425945
# started                0
# started    worth       0.33585
# started    talking     0.565599
# started    to          0.373348
# started    ,           0.261742
# started    ”           0.241422
# started    said        0.360254
# started    Thrun       0
# started    ,           0.261742
# started    now         0.583741
# started    the         0.396648
# started    co          0.129399
# started    -           0.145105
# started    founder     0.305061
# started    and         0.39468
# started    CEO         0.0257511
# started    of          0.331869
# started                0
# started    online      0.283055
# started    higher      0.197171
# started    education   0.279861
# started    startup     0.310791
# started    Udacity     0
# started    ,           0.261742
# started    in          0.376777
# started    an          0.284286
# started    interview   0.286577
# started    with        0.336244
# started                0
# started    Recode     -0.0866783
# started    earlier     0.543599
# started    this        0.385378
# started    week        0.507258
# started    .           0.277835
# working    When        0.573928
# working    Sebastian  -0.0572483
# working    Thrun       0
# working    started     0.557308
# working    working     1
# working    on          0.400102
# working    self        0.338705
# working    -           0.0959065
# working    driving     0.392546
# working    cars        0.235885
# working    at          0.321632
# working    Google      0.242153
# working    in          0.451865
# working    2007        0.101577
# working    ,           0.235672
# working    few         0.514101
# working    people      0.523614
# working    outside     0.519361
# working    of          0.358318
# working    the         0.458209
# working    company     0.464774
# working    took        0.45989
# working    him         0.433141
# working                0
# working    seriously   0.400802
# working    .           0.326977
# working    “           0.2362
# working    I           0.397114
# working    can         0.431096
# working    tell        0.467595
# working    you         0.452089
# working    very        0.497086
# working    senior      0.390766
# working    CEOs       -0.069167
# working    of          0.358318
# working    major       0.424272
# working    American    0.221703
# working                0
# working    car         0.246964
# working    companies   0.422764
# working    would       0.506694
# working    shake       0.207742
# working    my          0.496172
# working    hand        0.419918
# working    and         0.477559
# working    turn        0.430538
# working    away        0.375102
# working    because     0.524735
# working    I           0.397114
# working    was         0.456881
# working    n’t         0.341901
# working                0
# working    worth       0.336819
# working    talking     0.507793
# working    to          0.477674
# working    ,           0.235672
# working    ”           0.227301
# working    said        0.349036
# working    Thrun       0
# working    ,           0.235672
# working    now         0.542502
# working    the         0.458209
# working    co          0.178441
# working    -           0.0959065
# working    founder     0.217163
# working    and         0.477559
# working    CEO         0.106244
# working    of          0.358318
# working                0
# working    online      0.246288
# working    higher      0.343742
# working    education   0.4462
# working    startup     0.33413
# working    Udacity     0
# working    ,           0.235672
# working    in          0.451865
# working    an          0.39189
# working    interview   0.296893
# working    with        0.521648
# working                0
# working    Recode     -0.0395756
# working    earlier     0.409759
# working    this        0.419057
# working    week        0.43504
# working    .           0.326977
# on         When        0.425128
# on         Sebastian  -0.0275338
# on         Thrun       0
# on         started     0.428783
# on         working     0.400102
# on         on          1
# on         self        0.254135
# on         -           0.169642
# on         driving     0.336344
# on         cars        0.245936
# on         at          0.444324
# on         Google      0.248223
# on         in          0.433614
# on         2007        0.228951
# on         ,           0.267381
# on         few         0.401559
# on         people      0.348558
# on         outside     0.366343
# on         of          0.430575
# on         the         0.492559
# on         company     0.25275
# on         took        0.363636
# on         him         0.410254
# on                     0
# on         seriously   0.293717
# on         .           0.290286
# on         “           0.197767
# on         I           0.274579
# on         can         0.376789
# on         tell        0.288605
# on         you         0.404201
# on         very        0.368639
# on         senior      0.135815
# on         CEOs       -0.164891
# on         of          0.430575
# on         major       0.326857
# on         American    0.182261
# on                     0
# on         car         0.312865
# on         companies   0.236941
# on         would       0.384821
# on         shake       0.185307
# on         my          0.445727
# on         hand        0.418481
# on         and         0.446458
# on         turn        0.389839
# on         away        0.396775
# on         because     0.380659
# on         I           0.274579
# on         was         0.353075
# on         n’t         0.20828
# on                     0
# on         worth       0.317215
# on         talking     0.366724
# on         to          0.428844
# on         ,           0.267381
# on         ”           0.183627
# on         said        0.303325
# on         Thrun       0
# on         ,           0.267381
# on         now         0.398522
# on         the         0.492559
# on         co          0.128357
# on         -           0.169642
# on         founder     0.0871765
# on         and         0.446458
# on         CEO        -0.00892992
# on         of          0.430575
# on                     0
# on         online      0.368105
# on         higher      0.322872
# on         education   0.253586
# on         startup     0.137512
# on         Udacity     0
# on         ,           0.267381
# on         in          0.433614
# on         an          0.301607
# on         interview   0.267782
# on         with        0.41658
# on                     0
# on         Recode     -0.154627
# on         earlier     0.4063
# on         this        0.41738
# on         week        0.375478
# on         .           0.290286
# self       When        0.400002
# self       Sebastian   0.0854463
# self       Thrun       0
# self       started     0.237158
# self       working     0.338705
# self       on          0.254135
# self       self        1
# self       -           0.119083
# self       driving     0.308152
# self       cars        0.173742
# self       at          0.153478
# self       Google      0.233208
# self       in          0.30786
# self       2007        0.0107002
# self       ,           0.232654
# self       few         0.274089
# self       people      0.408415
# self       outside     0.309037
# self       of          0.27951
# self       the         0.285705
# self       company     0.239373
# self       took        0.192351
# self       him         0.34872
# cars       to          0.24661
# cars       ,           0.212059
# cars       ”           0.11892
# cars       said        0.145305
# cars       Thrun       0
# cars       ,           0.212059
# cars       now         0.26994
# cars       the         0.270967
# cars       co          0.197917
# cars       -           0.0653257
# cars       founder    -0.0177923
# cars       and         0.301795
# cars       CEO         0.106883
# cars       of          0.27384
# cars                   0
# cars       online      0.230302
# cars       higher      0.264425
# cars       education   0.165829
# cars       startup     0.14787
# cars       Udacity     0
# cars       ,           0.212059
# cars       in          0.311124
# cars       an          0.171368
# cars       interview   0.0269115
# cars       with        0.223205
# cars                   0
# cars       Recode     -0.0282136
# cars       earlier     0.224645
# cars       this        0.227804
# cars       week        0.185263
# cars       .           0.218993
# at         When        0.363292
# at         Sebastian   0.000280082
# at         Thrun       0
# at         started     0.331964
# at         working     0.321632
# at         on          0.444324
# at         self        0.153478
# at         -           0.26361
# at         driving     0.269065
# at         cars        0.164005
# at         at          1
# at         Google      0.101987
# at         in          0.365596
# at         2007        0.329168
# at         ,           0.31745
# at         few         0.318855
# at         people      0.264686
# at         outside     0.419543
# at         of          0.379296
# at         the         0.396577
# at         company     0.237593
# at         took        0.32795
# at         him         0.328434
# at                     0
# at         seriously   0.236295
# at         .           0.330711
# at         “           0.107759
# at         I           0.241991
# at         can         0.314243
# at         tell        0.268542
# at         you         0.345248
# at         very        0.333033
# at         senior      0.195517
# at         CEOs       -0.158537
# at         of          0.379296
# at         major       0.235316
# at         American    0.123452
# at                     0
# at         car         0.223832
# at         companies   0.205363
# at         would       0.320931
# at         shake       0.167073
# at         my          0.289706
# at         hand        0.257333
# at         and         0.285238
# at         turn        0.278563
# at         away        0.352487
# at         because     0.302504
# at         I           0.241991
# at         was         0.373146
# at         n’t         0.161613
# at                     0
# at         worth       0.280664
# at         talking     0.294383
# at         to          0.374437
# at         ,           0.31745
# at         ”           0.108304
# at         said        0.334519
# at         Thrun       0
# at         ,           0.31745
# at         now         0.372947
# at         the         0.396577
# at         co          0.101175
# at         -           0.26361
# at         founder     0.122456
# at         and         0.285238
# at         CEO        -0.000601522
# at         of          0.379296
# at                     0
# at         online      0.280271
# at         higher      0.284965
# at         education   0.225689
# at         startup     0.149064
# at         Udacity     0
# at         ,           0.31745
# at         in          0.365596
# at         an          0.27498
# at         interview   0.240952
# at         with        0.299765
# at                     0
# at         Recode     -0.124901
# at         earlier     0.290378
# at         this        0.259744
# at         week        0.299709
# at         .           0.330711
# Google     When        0.276873
# Google     Sebastian   0.185563
# Google     Thrun       0
# Google     started     0.239677
# Google     working     0.242153
# Google     on          0.248223
# Google     self        0.233208
# Google     -          -0.00881409
# Google     driving     0.166915
# Google     cars        0.19755
# Google     at          0.101987
# Google     Google      1
# Google     in          0.166842
# Google     2007        0.0933911
# Google     ,           0.220222
# Google     few         0.29476
# Google     people      0.337965
# Google     outside     0.127275
# Google     of          0.145634
# Google     the         0.219899
# Google     company     0.248267
# Google     took        0.167619
# Google     him         0.20258
# Google                 0
# Google     seriously   0.287047
# Google     .           0.235253
# Google     “           0.247875
# Google     I           0.420972
# Google     can         0.293661
# Google     tell        0.363548
# Google     you         0.362606
# Google     very        0.236309
# Google     senior      0.0751809
# Google     CEOs        0.0828341
# Google     of          0.145634
# Google     major       0.168454
# Google     American    0.326999
# Google                 0
# Google     car         0.236042
# Google     companies   0.250293
# Google     would       0.28848
# Google     shake       0.185779
# Google     my          0.347738
# Google     hand        0.208856
# Google     and         0.181712
# Google     turn        0.311013
# Google     away        0.201356
# Google     because     0.32441
# Google     I           0.420972
# Google     was         0.199237
# Google     n’t         0.360892
# Google                 0
# Google     worth       0.253653
# Google     talking     0.302501
# Google     to          0.256439
# Google     ,           0.220222
# Google     ”           0.243078
# Google     said        0.109781
# Google     Thrun       0
# Google     ,           0.220222
# Google     now         0.318382
# Google     the         0.219899
# Google     co          0.328236
# Google     -          -0.00881409
# Google     founder     0.137174
# Google     and         0.181712
# Google     CEO         0.344646
# Google     of          0.145634
# Google                 0
# Google     online      0.391193
# Google     higher      0.151155
# Google     education   0.219229
# Google     startup     0.333155
# Google     Udacity     0
# Google     ,           0.220222
# Google     in          0.166842
# Google     an          0.176633
# Google     interview   0.182995
# Google     with        0.18365
# Google                 0
# Google     Recode      0.125898
# Google     earlier     0.202294
# Google     this        0.326282
# Google     week        0.186935
# Google     .           0.235253
# in         When        0.487571
# in         Sebastian  -0.0515842
# in         Thrun       0
# in         started     0.376777
# in         working     0.451865
# in         on          0.433614
# in         self        0.30786
# in         -           0.118768
# in         driving     0.337053
# in         cars        0.311124
# in         at          0.365596
# in         Google      0.166842
# in         in          1
# in         2007        0.21289
# in         ,           0.301805
# in         few         0.403038
# in         people      0.427421
# in         outside     0.536591
# in         of          0.542424
# in         the         0.555486
# in         company     0.318369
# in         took        0.389529
# in         him         0.369312
# in                     0
# in         seriously   0.286957
# in         .           0.300468
# in         “           0.18983
# in         I           0.278343
# in         can         0.421013
# in         tell        0.271984
# in         you         0.377713
# in         very        0.419822
# in         senior      0.245418
# in         CEOs       -0.167283
# in         of          0.542424
# in         major       0.405151
# in         American    0.205881
# in                     0
# in         car         0.318541
# in         companies   0.344452
# in         would       0.402194
# in         shake       0.165495
# in         my          0.363233
# in         hand        0.38123
# in         and         0.476667
# in         turn        0.354644
# in         away        0.413752
# in         because     0.428777
# in         I           0.278343
# in         was         0.432392
# in         n’t         0.235823
# in                     0
# in         worth       0.314258
# in         talking     0.319718
# in         to          0.471923
# in         ,           0.301805
# in         ”           0.21945
# in         said        0.217848
# in         Thrun       0
# in         ,           0.301805
# in         now         0.405358
# in         the         0.555486
# in         co          0.130757
# in         -           0.118768
# in         founder     0.0974681
# in         and         0.476667
# in         CEO        -0.0549641
# in         of          0.542424
# in                     0
# in         online      0.33106
# in         higher      0.351712
# in         education   0.345526
# in         startup     0.132864
# in         Udacity     0
# in         ,           0.301805
# in         in          1
# in         an          0.442337
# in         interview   0.207187
# in         with        0.461608
# in                     0
# in         Recode     -0.0983321
# in         earlier     0.389339
# in         this        0.430666
# in         week        0.362885
# in         .           0.300468
# 2007       When        0.13787
# 2007       Sebastian   0.0363751
# 2007       Thrun       0
# ,          away        0.289143
# ,          because     0.364348
# ,          I           0.202096
# ,          was         0.330597
# ,          n’t         0.214585
# ,                      0
# ,          worth       0.216459
# ,          talking     0.262196
# ,          to          0.260884
# ,          ,           1
# ,          ”           0.158998
# ,          said        0.331088
# ,          Thrun       0
# ,          ,           1
# ,          now         0.356668
# ,          the         0.207785
# ,          co          0.0970968
# ,          -           0.213183
# ,          founder     0.161703
# ,          and         0.466192
# ,          CEO         0.0356713
# ,          of          0.246289
# ,                      0
# ,          online      0.21538
# ,          higher      0.19073
# ,          education   0.213639
# ,          startup     0.0918045
# ,          Udacity     0
# ,          ,           1
# ,          in          0.301805
# ,          an          0.229555
# ,          interview   0.173629
# ,          with        0.307459
# ,                      0
# ,          Recode     -0.0965454
# ,          earlier     0.220791
# ,          this        0.235107
# ,          week        0.207099
# ,          .           0.421524
# few        When        0.600293
# few        Sebastian  -0.0448438
# few        Thrun       0
# few        started     0.558763
# few        working     0.514101
# few        on          0.401559
# few        self        0.274089
# few        -           0.102201
# few        driving     0.349544
# few        cars        0.352376
# few        at          0.318855
# few        Google      0.29476
# few        in          0.403038
# few        2007        0.106948
# few        ,           0.24966
# few        few         1
# few        people      0.590229
# few        outside     0.468764
# few        of          0.461632
# few        the         0.512975
# few        company     0.358877
# few        took        0.601236
# few        him         0.510245
# few                    0
# few        seriously   0.490149
# few        .           0.328123
# few        “           0.31086
# few        I           0.423069
# few        can         0.511694
# few        tell        0.540141
# few        you         0.553495
# few        very        0.650721
# few        senior      0.273722
# few        CEOs       -0.0371709
# few        of          0.461632
# few        major       0.502137
# few        American    0.1986
# few                    0
# few        car         0.33461
# few        companies   0.401067
# few        would       0.571982
# few        shake       0.338389
# few        my          0.583571
# few        hand        0.462068
# few        and         0.471437
# few        turn        0.524922
# few        away        0.583127
# few        because     0.622486
# few        I           0.423069
# few        was         0.488474
# few        n’t         0.490954
# few                    0
# few        worth       0.504108
# few        talking     0.555519
# few        to          0.45638
# few        ,           0.24966
# few        ”           0.264089
# few        said        0.309225
# few        Thrun       0
# few        ,           0.24966
# few        now         0.565639
# few        the         0.512975
# few        co          0.117929
# few        -           0.102201
# few        founder     0.171904
# few        and         0.471437
# few        CEO         0.0112081
# few        of          0.461632
# few                    0
# few        online      0.323232
# few        higher      0.370739
# few        education   0.241616
# few        startup     0.278375
# few        Udacity     0
# few        ,           0.24966
# few        in          0.403038
# few        an          0.350939
# few        interview   0.33795
# few        with        0.482894
# few                    0
# few        Recode     -0.0454432
# few        earlier     0.637201
# few        this        0.506912
# few        week        0.562833
# few        .           0.328123
# people     When        0.585984
# people     Sebastian  -0.0338226
# people     Thrun       0
# people     started     0.423032
# people     working     0.523614
# people     on          0.348558
# people     self        0.408415
# people     -           0.137734
# people     driving     0.40235
# people     cars        0.400668
# people     at          0.264686
# people     Google      0.337965
# people     in          0.427421
# people     2007        0.0747788
# people     ,           0.26528
# people     few         0.590229
# people     people      1
# people     outside     0.476402
# people     of          0.498037
# people     the         0.478305
# people     company     0.356834
# people     took        0.456959
# people     him         0.507904
# people                 0
# outside    this        0.404272
# outside    week        0.332435
# outside    .           0.326851
# of         When        0.455727
# of         Sebastian  -0.0989138
# of         Thrun       0
# of         started     0.331869
# of         working     0.358318
# of         on          0.430575
# of         self        0.27951
# of         -           0.106938
# of         driving     0.356541
# of         cars        0.27384
# of         at          0.379296
# of         Google      0.145634
# of         in          0.542424
# of         2007        0.219276
# of         ,           0.246289
# of         few         0.461632
# of         people      0.498037
# of         outside     0.381013
# of         of          1
# ...
# with                   0
# with       online      0.301874
# with       higher      0.353307
# with       education   0.288502
# with       startup     0.152265
# with       Udacity     0
# with       ,           0.307459
# with       in          0.461608
# with       an          0.553983
# with       interview   0.309681
# with       with        1
# with                   0
# with       Recode     -0.0901491
# with       earlier     0.387998
# with       this        0.50803
# with       week        0.352064
# with       .           0.363602
#            When        0
#            Sebastian   0
#            Thrun       0
#            started     0
#            working     0
#            on          0
#            self        0
#            -           0
#            driving     0
#            cars        0
#            at          0
#            Google      0
#            in          0
#            2007        0
#            ,           0
#            few         0
#            people      0
#            outside     0
#            of          0
#            the         0
#            company     0
#            took        0
#            him         0
#                        0
#            seriously   0
#            .           0
#            “           0
#            I           0
#            can         0
#            tell        0
#            you         0
#            very        0
#            senior      0
#            CEOs        0
#            of          0
#            major       0
#            American    0
#                        0
#            car         0
#            companies   0
#            would       0
#            shake       0
#            my          0
#            hand        0
#            and         0
#            turn        0
#            away        0
#            because     0
#            I           0
#            was         0
#            n’t         0
#                        0
#            worth       0
#            talking     0
#            to          0
#            ,           0
#            ”           0
#            said        0
#            Thrun       0
#            ,           0
#            now         0
#            the         0
#            co          0
#            -           0
#            founder     0
#            and         0
#            CEO         0
#            of          0
#                        0
#            online      0
#            higher      0
#            education   0
#            startup     0
#            Udacity     0
#            ,           0
#            in          0
#            an          0
#            interview   0
#            with        0
#                        1
#            Recode      0
#            earlier     0
#            this        0
#            week        0
#            .           0
# Recode     When       -0.0516174
# Recode     Sebastian   0.0127392
# Recode     Thrun       0
# Recode     started    -0.0866783
# Recode     working    -0.0395756
# Recode     on         -0.154627
# Recode     self       -0.00608697
# Recode     -          -0.0729984
# Recode     driving    -0.054677
# Recode     cars       -0.0282136
# Recode     at         -0.124901
# Recode     Google      0.125898
# Recode     in         -0.0983321
# Recode     2007       -0.0944309
# Recode     ,          -0.0965454
# Recode     few        -0.0454432
# Recode     people     -0.0176777
# Recode     outside    -0.1535
# Recode     of         -0.134149
# Recode     the        -0.0935496
# Recode     company    -0.0765536
# Recode     took       -0.039819
# Recode     him        -0.0920004
# Recode                 0
# Recode     seriously  -0.0648935
# Recode     .          -0.0814529
# Recode     “          -0.0963382
# Recode     I           0.00505615
# Recode     can         0.0154347
# Recode     tell        0.0085604
# Recode     you        -0.00837727
# Recode     very       -0.113599
# Recode     senior     -0.126743
# Recode     CEOs        0.0731572
# Recode     of         -0.134149
# Recode     major      -0.0428501
# Recode     American   -0.080015
# Recode                 0
# Recode     car        -0.00606609
# Recode     companies  -0.0803807
# Recode     would      -0.0264755
# Recode     shake       0.011822
# Recode     my         -0.0369134
# Recode     hand       -0.103898
# Recode     and        -0.100082
# Recode     turn        0.0524834
# Recode     away       -0.106404
# Recode     because    -0.0389778
# Recode     I           0.00505615
# Recode     was        -0.105858
# Recode     n’t         0.00369095
# Recode                 0
# Recode     worth      -0.0239817
# Recode     talking    -0.112718
# Recode     to          0.0584871
# Recode     ,          -0.0965454
# Recode     ”          -0.112846
# Recode     said       -0.120788
# Recode     Thrun       0
# Recode     ,          -0.0965454
# Recode     now        -0.0511336
# Recode     the        -0.0935496
# Recode     co         -0.0276159
# Recode     -          -0.0729984
# Recode     founder    -0.0560555
# Recode     and        -0.100082
# Recode     CEO         0.00183008
# Recode     of         -0.134149
# Recode                 0
# Recode     online     -0.0549986
# Recode     higher     -0.0488622
# Recode     education  -0.0760464
# Recode     startup     0.0927448
# Recode     Udacity     0
# Recode     ,          -0.0965454
# Recode     in         -0.0983321
# Recode     an         -0.095776
# Recode     interview  -0.0813026
# Recode     with       -0.0901491
# Recode                 0
# Recode     Recode      1
# Recode     earlier    -0.0376374
# Recode     this       -0.0840091
# Recode     week       -0.134621
# Recode     .          -0.0814529
# earlier    When        0.603529
# earlier    Sebastian  -0.108409
# earlier    Thrun       0
# earlier    started     0.543599
# earlier    working     0.409759
# earlier    on          0.4063
# earlier    self        0.171104
# earlier    -          -0.00614009
# earlier    driving     0.29535
# earlier    cars        0.224645
# earlier    at          0.290378
# earlier    Google      0.202294
# earlier    in          0.389339
# earlier    2007        0.228229
# earlier    ,           0.220791
# earlier    few         0.637201
# earlier    people      0.381574
# earlier    outside     0.367844
# earlier    of          0.358283
# earlier    the         0.484715
# earlier    company     0.334324
# earlier    took        0.621808
# earlier    him         0.470672
# earlier                0
# earlier    seriously   0.449592
# earlier    .           0.341272
# earlier    “           0.295109
# earlier    I           0.295446
# earlier    can         0.308902
# earlier    tell        0.406322
# earlier    you         0.310779
# earlier    very        0.41469
# earlier    senior      0.336723
# earlier    CEOs       -0.13014
# earlier    of          0.358283
# earlier    major       0.454843
# earlier    American    0.111626
# earlier                0
# earlier    car         0.244652
# earlier    companies   0.274063
# earlier    would       0.52679
# earlier    shake       0.199482
# earlier    my          0.457008
# earlier    hand        0.336278
# earlier    and         0.366226
# earlier    turn        0.383137
# earlier    away        0.39713
# earlier    because     0.56983
# earlier    I           0.295446
# earlier    was         0.595726
# earlier    n’t         0.364348
# earlier                0
# earlier    worth       0.374512
# earlier    talking     0.441864
# earlier    to          0.394486
# earlier    ,           0.220791
# earlier    ”           0.303208
# earlier    said        0.452563
# earlier    Thrun       0
# earlier    ,           0.220791
# earlier    now         0.530823
# earlier    the         0.484715
# earlier    co          0.0156068
# earlier    -          -0.00614009
# earlier    founder     0.262066
# earlier    and         0.366226
# earlier    CEO         0.00364688
# earlier    of          0.358283
# earlier                0
# earlier    online      0.201765
# earlier    higher      0.38876
# earlier    education   0.243169
# earlier    startup     0.212867
# earlier    Udacity     0
# earlier    ,           0.220791
# earlier    in          0.389339
# earlier    an          0.363436
# earlier    interview   0.423921
# earlier    with        0.387998
# earlier                0
# week       now         0.510619
# week       the         0.378837
# week       co          0.0680901
# week       -           0.159855
# week       founder     0.151926
# week       and         0.308779
# week       CEO         0.0471903
# week       of          0.344222
# week                   0
# week       online      0.260591
# week       higher      0.256375
# week       education   0.238112
# week       startup     0.164481
# week       Udacity     0
# week       ,           0.207099
# week       in          0.362885
# week       an          0.300221
# week       interview   0.461685
# week       with        0.352064
# week                   0
# week       Recode     -0.134621
# week       earlier     0.631343
# week       this        0.529656
# week       week        1
# week       .           0.306639
# .          When        0.437521
# .          Sebastian  -0.0209733
# .          Thrun       0
# .          started     0.277835
# .          working     0.326977
# .          on          0.290286
# .          self        0.320757
# .          -           0.241013
# .          driving     0.295193
# .          cars        0.218993
# .          at          0.330711
# .          Google      0.235253
# .          in          0.300468
# .          2007        0.284838
# .          ,           0.421524
# .          few         0.328123
# .          people      0.347744
# .          outside     0.326851
# .          of          0.314684
# .          the         0.311351
# .          company     0.267577
# .          took        0.29914
# .          him         0.380523
# .                      0
# .          seriously   0.374537
# .          .           1
# .          “           0.221556
# .          I           0.377928
# .          can         0.387569
# .          tell        0.351098
# .          you         0.389099
# .          very        0.4173
# .          senior      0.212337
# .          CEOs       -0.117487
# .          of          0.314684
# .          major       0.281376
# .          American    0.232716
# .                      0
# .          car         0.272436
# .          companies   0.214816
# .          would       0.390647
# .          shake       0.219333
# .          my          0.295956
# .          hand        0.360211
# .          and         0.432417
# .          turn        0.346648
# .          away        0.350795
# .          because     0.405417
# .          I           0.377928
# .          was         0.389106
# .          n’t         0.229253
# .                      0
# .          worth       0.366333
# .          talking     0.299526
# .          to          0.358275
# .          ,           0.421524
# .          ”           0.368363
# .          said        0.248359
# .          Thrun       0
# .          ,           0.421524
# .          now         0.452297
# .          the         0.311351
# .          co          0.236421
# .          -           0.241013
# .          founder     0.0928578
# .          and         0.432417
# .          CEO         0.0497973
# .          of          0.314684
# .                      0
# .          online      0.289034
# .          higher      0.26175
# .          education   0.254915
# .          startup     0.15568
# .          Udacity     0
# .          ,           0.421524
# .          in          0.300468
# .          an          0.333159
# .          interview   0.206069
# .          with        0.363602
# .                      0
# .          Recode     -0.0814529
# .          earlier     0.341272
# .          this        0.375738
# .          week        0.306639
# .          .           1

# %%
tokens = nlp(u'dog cat banana afskfsd')

for token in tokens:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# dog True 7.0336733 False
# cat True 6.6808186 False
# banana True 6.700014 False
# afskfsd False 0.0 True

# %%
spacy.info()
# Out:
#     Info about spaCy
#
#     spaCy version      2.0.12
#     Location           I:\ML\Anaconda3\envs\dlwin36\lib\site-packages\spacy
#     Platform           Windows-10-10.0.17134-SP0
#     Python version     3.6.6
#     Models
# {'spaCy version': '2.0.12',
#  'Location': 'I:\\ML\\Anaconda3\\envs\\dlwin36\\lib\\site-packages\\spacy',
#  'Platform': 'Windows-10-10.0.17134-SP0',
#  'Python version': '3.6.6',
#  'Models': ''}

# %%
#Models
#https://github.com/explosion/spacy-models/releases/download/en_vectors_web_lg-2.0.0/en_vectors_web_lg-2.0.0.tar.gz
#https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.0.0/en_core_web_lg-2.0.0.tar.gz
